# %% [markdown]
# # Plot Training Loss

# %%
import matplotlib.pyplot as plt
import json

# %%
training_time = "2020-03-03 22:53"

# %%
config = open("../checkpoints/train/{}/config.txt".format(training_time), "r").read()
config = str(config.replace("'", '"').replace("True", 'true'))
config = json.loads(config)
config
# Out:
# {'rnn_units': 512,
#  'rnn_type': 'LSTM',
#  'tokenizer': 'BERT',
#  'word_embedding': 'BERT',
#  'vocab_size': 3000,
#  'combine_strategy': 'merge',
#  'combine_layer': 'concat',
#  'image_context_size': 256,
#  'word_embedding_dim': 256,
#  'batch_size': 64,
#  'data_size': 30000,
#  'use_mapping': True,
#  'learning_rate': 0.001,
#  'max_caption_length': 25,
#  'image_feature_extractor': 'xception'}

# %%
log = open("../checkpoints/train/{}/log.txt".format(training_time), "r").readlines()
log
# Out:
# [' ./checkpoints/train/2020-03-03 22:53 Epoch 1 Batch 500 Loss 4.3531\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 1 Batch 1000 Loss 3.5264\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 1 Batch 1500 Loss 2.9856\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 1 Batch 2000 Loss 3.3975\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 1 Batch 2500 Loss 3.0556\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 1 Batch 3000 Loss 4.7157\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 1 Batch 3500 Loss 3.1297\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 1 Batch 4000 Loss 3.4085\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 2 Batch 500 Loss 3.2416\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 2 Batch 1000 Loss 2.8119\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 2 Batch 1500 Loss 2.4070\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 2 Batch 2000 Loss 2.9103\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 2 Batch 2500 Loss 2.6527\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 2 Batch 3000 Loss 4.0324\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 2 Batch 3500 Loss 2.6617\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 2 Batch 4000 Loss 2.9770\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 3 Batch 500 Loss 2.9376\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 3 Batch 1000 Loss 2.4568\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 3 Batch 1500 Loss 2.2121\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 3 Batch 2000 Loss 2.6683\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 3 Batch 2500 Loss 2.5845\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 3 Batch 3000 Loss 3.7166\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 3 Batch 3500 Loss 2.4342\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 3 Batch 4000 Loss 2.7331\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 4 Batch 500 Loss 2.7059\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 4 Batch 1000 Loss 2.2757\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 4 Batch 1500 Loss 2.0388\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 4 Batch 2000 Loss 2.5226\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 4 Batch 2500 Loss 2.5107\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 4 Batch 3000 Loss 3.4070\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 4 Batch 3500 Loss 2.2817\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 4 Batch 4000 Loss 2.5805\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 5 Batch 500 Loss 2.6048\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 5 Batch 1000 Loss 2.0924\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 5 Batch 1500 Loss 1.9007\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 5 Batch 2000 Loss 2.3695\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 5 Batch 2500 Loss 2.4245\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 5 Batch 3000 Loss 2.9543\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 5 Batch 3500 Loss 2.1351\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 5 Batch 4000 Loss 2.3021\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 6 Batch 500 Loss 2.4218\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 6 Batch 1000 Loss 1.8829\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 6 Batch 1500 Loss 1.7188\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 6 Batch 2000 Loss 2.1823\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 6 Batch 2500 Loss 2.2840\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 6 Batch 3000 Loss 2.6448\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 6 Batch 3500 Loss 1.9462\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 6 Batch 4000 Loss 2.2484\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 7 Batch 500 Loss 2.3182\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 7 Batch 1000 Loss 1.6707\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 7 Batch 1500 Loss 1.6753\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 7 Batch 2000 Loss 2.0270\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 7 Batch 2500 Loss 2.1649\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 7 Batch 3000 Loss 2.4519\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 7 Batch 3500 Loss 1.7663\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 7 Batch 4000 Loss 2.1566\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 8 Batch 500 Loss 2.1605\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 8 Batch 1000 Loss 1.5831\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 8 Batch 1500 Loss 1.5658\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 8 Batch 2000 Loss 1.9921\n',
#  ' ./checkpoints/train/2020-03-03 22:53 Epoch 8 Batch 2500 Loss 2.0904\n']

# %%
loss = [float(x[x.find('Loss') + 5 :].strip()) for x in log]

plt.figure(figsize=(13,13))
plt.plot(loss);
