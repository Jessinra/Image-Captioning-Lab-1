# %% [markdown]
# # Plot Training Loss

# %%
import matplotlib.pyplot as plt
import json

# %%
training_time = "2020-03-04 16:30"

# %%
config = open("../checkpoints/train/{}/config.txt".format(training_time), "r").read()
config = str(config.replace("'", '"').replace("True", 'true'))
config = json.loads(config)
config
# Out:
# {'rnn_units': 1024,
#  'rnn_type': 'LSTM',
#  'tokenizer': 'BERT',
#  'word_embedding': 'BERT',
#  'vocab_size': 3000,
#  'combine_strategy': 'merge',
#  'combine_layer': 'concat',
#  'image_context_size': 256,
#  'word_embedding_dim': 256,
#  'batch_size': 32,
#  'data_size': 30000,
#  'use_mapping': True,
#  'learning_rate': 0.001,
#  'max_caption_length': 25,
#  'image_feature_extractor': 'xception',
#  'use_sequence': True}

# %%
log = open("../checkpoints/train/{}/log.txt".format(training_time), "r").readlines()
log
# Out:
# [' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 100 Loss 5.9497\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 200 Loss 4.5656\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 300 Loss 4.5142\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 400 Loss 5.3806\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 500 Loss 4.1390\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 600 Loss 5.0672\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 700 Loss 3.4989\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 800 Loss 3.2057\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 900 Loss 5.2454\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 1000 Loss 3.8442\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 1100 Loss 4.9578\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 1200 Loss 4.0954\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 1300 Loss 3.6249\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 1400 Loss 3.6683\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 1500 Loss 4.8989\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 1600 Loss 4.2958\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 1700 Loss 4.0910\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 1800 Loss 3.3261\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 1900 Loss 5.1175\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 2000 Loss 3.9027\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 2100 Loss 4.1501\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 2200 Loss 3.7040\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 2300 Loss 4.8183\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 2400 Loss 3.5940\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 2500 Loss 3.0662\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 2600 Loss 3.4889\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 2700 Loss 4.0646\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 2800 Loss 3.4268\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 2900 Loss 3.5918\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 3000 Loss 3.8633\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 3100 Loss 4.6188\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 3200 Loss 3.6553\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 3300 Loss 4.6538\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 3400 Loss 5.1367\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 3500 Loss 3.7070\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 3600 Loss 3.1855\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 3700 Loss 2.8905\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 3800 Loss 3.0593\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 3900 Loss 3.6982\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 4000 Loss 3.8049\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 4100 Loss 4.0131\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 4200 Loss 3.0706\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 4300 Loss 3.5172\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 4400 Loss 5.0945\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 4500 Loss 3.1801\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 4600 Loss 3.3347\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 4700 Loss 3.7860\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 4800 Loss 3.1118\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 4900 Loss 3.8231\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 5000 Loss 3.4868\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 5100 Loss 3.4204\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 5200 Loss 2.6377\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 5300 Loss 2.8633\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 5400 Loss 2.9282\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 5500 Loss 3.4596\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 5600 Loss 3.1219\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 5700 Loss 3.6246\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 5800 Loss 2.7224\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 5900 Loss 2.6737\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 6000 Loss 4.3769\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 6100 Loss 3.1831\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 6200 Loss 3.7583\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 6300 Loss 3.4236\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 6400 Loss 4.2026\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 6500 Loss 4.3598\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 6600 Loss 3.9385\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 6700 Loss 3.2898\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 6800 Loss 4.0478\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 6900 Loss 3.7373\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 7000 Loss 3.3673\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 7100 Loss 4.4049\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 7200 Loss 3.5857\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 7300 Loss 2.6451\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 7400 Loss 2.6671\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 7500 Loss 3.8464\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 7600 Loss 4.1488\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 7700 Loss 3.7335\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 7800 Loss 3.4273\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 7900 Loss 2.9823\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 8000 Loss 3.5678\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 8100 Loss 4.1147\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 8200 Loss 3.6754\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 8300 Loss 3.3110\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 1 Batch 8400 Loss 3.5711\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 100 Loss 3.6986\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 200 Loss 2.7799\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 300 Loss 3.0738\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 400 Loss 4.4087\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 500 Loss 3.5657\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 600 Loss 3.8549\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 700 Loss 2.7034\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 800 Loss 2.2504\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 900 Loss 4.0390\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 1000 Loss 3.0257\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 1100 Loss 4.1059\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 1200 Loss 3.3703\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 1300 Loss 2.7233\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 1400 Loss 3.1338\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 1500 Loss 4.4702\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 1600 Loss 3.6510\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 1700 Loss 2.8829\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 1800 Loss 2.5475\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 1900 Loss 4.2392\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 2000 Loss 3.4225\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 2100 Loss 3.0590\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 2200 Loss 3.5086\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 2300 Loss 4.3300\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 2400 Loss 2.7977\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 2500 Loss 2.6853\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 2600 Loss 2.9652\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 2700 Loss 4.1742\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 2800 Loss 2.7762\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 2900 Loss 2.8499\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 3000 Loss 3.2719\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 3100 Loss 3.9071\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 3200 Loss 2.7232\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 3300 Loss 4.6660\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 3400 Loss 4.3200\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 3500 Loss 3.1739\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 3600 Loss 2.6353\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 3700 Loss 2.3508\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 3800 Loss 2.5425\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 3900 Loss 3.1114\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 4000 Loss 3.2445\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 4100 Loss 3.0449\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 4200 Loss 2.6845\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 4300 Loss 2.8329\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 4400 Loss 4.2800\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 4500 Loss 2.8286\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 4600 Loss 2.9398\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 4700 Loss 3.4899\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 4800 Loss 2.6836\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 4900 Loss 3.1879\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 5000 Loss 3.0461\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 5100 Loss 2.8634\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 5200 Loss 2.1854\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 5300 Loss 2.9552\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 5400 Loss 2.4776\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 5500 Loss 2.8684\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 5600 Loss 2.7388\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 5700 Loss 3.1976\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 5800 Loss 2.3166\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 5900 Loss 2.5555\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 6000 Loss 3.7710\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 6100 Loss 2.8127\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 6200 Loss 3.1104\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 6300 Loss 3.0107\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 6400 Loss 3.4037\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 6500 Loss 3.6373\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 6600 Loss 3.2238\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 6700 Loss 3.0342\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 6800 Loss 3.3573\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 6900 Loss 3.0067\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 7000 Loss 3.0568\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 7100 Loss 3.6771\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 7200 Loss 3.0318\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 7300 Loss 2.2471\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 7400 Loss 2.2389\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 7500 Loss 3.5456\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 7600 Loss 3.7938\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 7700 Loss 3.3561\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 7800 Loss 2.8116\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 7900 Loss 2.4234\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 8000 Loss 3.3372\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 8100 Loss 3.8743\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 8200 Loss 3.0589\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 8300 Loss 2.7805\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 2 Batch 8400 Loss 3.4252\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 100 Loss 2.8380\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 200 Loss 2.1458\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 300 Loss 2.5896\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 400 Loss 4.2080\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 500 Loss 3.6714\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 600 Loss 3.2384\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 700 Loss 2.4111\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 800 Loss 2.3270\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 900 Loss 3.5647\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 1000 Loss 2.7369\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 1100 Loss 3.4131\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 1200 Loss 2.7947\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 1300 Loss 2.1493\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 1400 Loss 2.7797\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 1500 Loss 3.9772\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 1600 Loss 3.0026\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 1700 Loss 2.4591\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 1800 Loss 2.4809\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 1900 Loss 3.5201\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 2000 Loss 2.9604\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 2100 Loss 2.5301\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 2200 Loss 3.1213\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 2300 Loss 3.4738\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 2400 Loss 2.5723\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 2500 Loss 2.7489\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 2600 Loss 2.7839\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 2700 Loss 3.7123\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 2800 Loss 2.2923\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 2900 Loss 2.3178\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 3000 Loss 2.5318\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 3100 Loss 3.3317\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 3200 Loss 2.3564\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 3300 Loss 3.9638\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 3400 Loss 2.7525\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 3500 Loss 2.6087\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 3600 Loss 1.9555\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 3700 Loss 1.8696\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 3800 Loss 2.5231\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 3900 Loss 2.4805\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 4000 Loss 2.7333\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 4100 Loss 2.5695\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 4200 Loss 2.4866\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 4300 Loss 2.4807\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 4400 Loss 3.7846\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 4500 Loss 2.2770\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 4600 Loss 2.5568\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 4700 Loss 2.9238\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 4800 Loss 2.5558\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 4900 Loss 2.8002\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 5000 Loss 2.4928\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 5100 Loss 2.1166\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 5200 Loss 2.1263\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 5300 Loss 2.9521\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 5400 Loss 2.0240\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 5500 Loss 2.7058\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 5600 Loss 2.2729\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 5700 Loss 2.8570\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 5800 Loss 2.0772\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 5900 Loss 2.0433\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 6000 Loss 3.1960\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 6100 Loss 2.5616\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 6200 Loss 2.5395\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 6300 Loss 2.6359\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 6400 Loss 3.1670\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 6500 Loss 3.1913\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 6600 Loss 2.6041\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 6700 Loss 3.0205\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 6800 Loss 3.0920\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 6900 Loss 2.1253\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 7000 Loss 2.8224\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 7100 Loss 3.2558\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 7200 Loss 2.4843\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 7300 Loss 2.0659\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 7400 Loss 2.1125\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 7500 Loss 3.0989\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 7600 Loss 3.2609\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 7700 Loss 2.9643\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 7800 Loss 2.4611\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 7900 Loss 2.1046\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 8000 Loss 3.1560\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 8100 Loss 3.8932\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 8200 Loss 2.3599\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 8300 Loss 2.3190\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 3 Batch 8400 Loss 2.8904\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 100 Loss 2.3825\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 200 Loss 1.7414\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 300 Loss 2.1804\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 400 Loss 3.4547\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 500 Loss 3.0471\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 600 Loss 2.7381\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 700 Loss 2.1579\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 800 Loss 2.8704\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 900 Loss 3.2828\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 1000 Loss 2.3181\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 1100 Loss 2.9042\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 1200 Loss 2.4215\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 1300 Loss 1.8166\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 1400 Loss 2.3463\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 1500 Loss 3.6328\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 1600 Loss 2.0707\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 1700 Loss 1.8305\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 1800 Loss 1.9188\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 1900 Loss 3.0070\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 2000 Loss 2.5706\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 2100 Loss 1.8964\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 2200 Loss 2.8802\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 2300 Loss 3.0890\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 2400 Loss 2.3460\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 2500 Loss 2.3243\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 2600 Loss 2.5475\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 2700 Loss 3.1170\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 2800 Loss 1.6856\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 2900 Loss 1.5016\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 3000 Loss 2.1758\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 3100 Loss 3.3531\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 3200 Loss 2.0688\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 3300 Loss 3.3725\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 3400 Loss 1.8207\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 3500 Loss 2.0408\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 3600 Loss 1.7071\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 3700 Loss 1.5272\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 3800 Loss 1.9355\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 3900 Loss 2.0114\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 4000 Loss 2.4717\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 4100 Loss 2.1545\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 4200 Loss 2.4125\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 4300 Loss 2.3720\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 4400 Loss 3.3456\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 4500 Loss 1.7869\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 4600 Loss 2.4477\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 4700 Loss 2.5620\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 4800 Loss 2.3857\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 4900 Loss 2.1951\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 5000 Loss 2.3558\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 5100 Loss 1.6631\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 5200 Loss 1.9981\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 5300 Loss 2.6212\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 5400 Loss 1.8030\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 5500 Loss 2.3739\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 5600 Loss 2.0704\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 5700 Loss 2.4371\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 5800 Loss 1.9903\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 5900 Loss 1.9749\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 6000 Loss 2.9557\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 6100 Loss 2.5091\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 6200 Loss 2.2190\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 6300 Loss 2.5025\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 6400 Loss 2.8202\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 6500 Loss 3.1427\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 6600 Loss 2.5368\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 6700 Loss 2.3487\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 6800 Loss 3.1268\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 6900 Loss 1.9231\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 7000 Loss 2.7746\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 7100 Loss 2.0158\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 7200 Loss 2.2125\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 7300 Loss 1.6966\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 7400 Loss 2.1027\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 7500 Loss 2.6721\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 7600 Loss 2.6279\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 7700 Loss 2.5305\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 7800 Loss 2.0261\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 7900 Loss 1.7884\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 8000 Loss 2.8977\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 8100 Loss 3.3339\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 8200 Loss 2.2120\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 8300 Loss 2.5383\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 4 Batch 8400 Loss 2.5003\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 100 Loss 2.1600\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 200 Loss 1.5823\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 300 Loss 1.8441\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 400 Loss 3.5372\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 500 Loss 2.8483\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 600 Loss 2.0092\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 700 Loss 1.8972\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 800 Loss 1.7911\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 900 Loss 2.7350\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 1000 Loss 2.3792\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 1100 Loss 2.5475\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 1200 Loss 2.1440\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 1300 Loss 1.6621\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 1400 Loss 2.2323\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 1500 Loss 2.4758\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 1600 Loss 2.0989\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 1700 Loss 2.2781\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 1800 Loss 1.6759\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 1900 Loss 2.9221\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 2000 Loss 2.4763\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 2100 Loss 1.9052\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 2200 Loss 2.8947\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 2300 Loss 2.7976\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 2400 Loss 1.8498\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 2500 Loss 1.9581\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 2600 Loss 2.0714\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 2700 Loss 2.9233\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 2800 Loss 1.4991\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 2900 Loss 1.4239\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 3000 Loss 1.8619\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 3100 Loss 2.9937\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 3200 Loss 1.7345\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 3300 Loss 2.9724\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 3400 Loss 1.7825\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 3500 Loss 1.5788\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 3600 Loss 1.6824\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 3700 Loss 1.8005\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 3800 Loss 1.9688\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 3900 Loss 1.5279\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 4000 Loss 2.1588\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 4100 Loss 2.1349\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 4200 Loss 1.9158\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 4300 Loss 2.6452\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 4400 Loss 3.3035\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 4500 Loss 1.6614\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 4600 Loss 2.3677\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 4700 Loss 2.2967\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 4800 Loss 2.4682\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 4900 Loss 2.0392\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 5000 Loss 2.0283\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 5100 Loss 1.6116\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 5200 Loss 2.0000\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 5300 Loss 2.3427\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 5400 Loss 1.7444\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 5500 Loss 2.0411\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 5600 Loss 1.9503\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 5700 Loss 2.2861\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 5800 Loss 1.6066\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 5900 Loss 2.0845\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 6000 Loss 2.5012\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 6100 Loss 2.2458\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 6200 Loss 2.0721\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 6300 Loss 2.2676\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 6400 Loss 2.3157\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 6500 Loss 2.6562\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 6600 Loss 2.3778\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 6700 Loss 2.9105\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 6800 Loss 2.5190\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 6900 Loss 2.1614\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 7000 Loss 2.1256\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 7100 Loss 2.0105\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 7200 Loss 1.8217\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 7300 Loss 1.6232\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 7400 Loss 1.8663\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 7500 Loss 2.3041\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 7600 Loss 2.2206\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 7700 Loss 2.4408\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 7800 Loss 2.1065\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 7900 Loss 1.7269\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 8000 Loss 2.6595\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 8100 Loss 2.9917\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 8200 Loss 2.1519\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 8300 Loss 1.8732\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 5 Batch 8400 Loss 2.2767\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 100 Loss 1.8468\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 200 Loss 1.6662\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 300 Loss 2.3231\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 400 Loss 2.9446\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 500 Loss 2.8336\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 600 Loss 1.8642\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 700 Loss 1.4868\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 800 Loss 1.5118\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 900 Loss 2.5677\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 1000 Loss 2.2990\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 1100 Loss 2.2396\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 1200 Loss 1.9488\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 1300 Loss 1.2405\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 1400 Loss 1.8684\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 1500 Loss 2.3367\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 1600 Loss 1.7437\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 1700 Loss 1.7943\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 1800 Loss 1.2869\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 1900 Loss 2.4065\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 2000 Loss 2.2798\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 2100 Loss 1.4425\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 2200 Loss 2.2513\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 2300 Loss 2.8597\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 2400 Loss 1.9174\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 2500 Loss 1.9303\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 2600 Loss 2.0441\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 2700 Loss 3.0766\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 2800 Loss 1.3426\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 2900 Loss 1.3651\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 3000 Loss 1.6822\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 3100 Loss 2.7690\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 3200 Loss 1.6236\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 3300 Loss 2.8923\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 3400 Loss 1.5682\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 3500 Loss 1.7405\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 3600 Loss 1.3962\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 3700 Loss 1.7945\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 3800 Loss 1.8607\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 3900 Loss 1.4178\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 4000 Loss 1.6931\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 4100 Loss 1.9663\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 4200 Loss 2.0843\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 4300 Loss 3.3194\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 4400 Loss 3.2296\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 4500 Loss 1.7510\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 4600 Loss 2.1763\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 4700 Loss 1.9494\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 4800 Loss 1.8881\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 4900 Loss 1.7998\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 5000 Loss 1.9840\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 5100 Loss 1.3094\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 5200 Loss 1.8507\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 5300 Loss 2.2092\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 5400 Loss 1.7121\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 5500 Loss 1.9827\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 5600 Loss 1.6232\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 5700 Loss 1.8151\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 5800 Loss 1.5932\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 5900 Loss 1.7288\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 6000 Loss 2.3001\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 6100 Loss 2.1264\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 6200 Loss 2.2112\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 6300 Loss 1.8815\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 6400 Loss 2.7482\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 6500 Loss 2.6302\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 6600 Loss 2.3418\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 6700 Loss 2.5274\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 6800 Loss 2.1266\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 6900 Loss 1.9752\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 7000 Loss 1.7019\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 7100 Loss 1.5911\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 7200 Loss 1.8593\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 7300 Loss 1.3093\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 7400 Loss 1.8009\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 7500 Loss 2.3165\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 7600 Loss 2.1821\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 7700 Loss 2.2064\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 7800 Loss 2.0578\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 7900 Loss 1.6636\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 8000 Loss 2.7091\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 8100 Loss 3.2144\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 8200 Loss 1.7209\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 8300 Loss 1.9035\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 6 Batch 8400 Loss 1.5589\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 100 Loss 1.9529\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 200 Loss 1.2211\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 300 Loss 2.0463\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 400 Loss 3.0010\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 500 Loss 2.6322\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 600 Loss 1.7939\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 700 Loss 1.3594\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 800 Loss 2.2036\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 900 Loss 2.6276\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 1000 Loss 2.1872\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 1100 Loss 1.8277\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 1200 Loss 1.6036\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 1300 Loss 1.3774\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 1400 Loss 1.4621\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 1500 Loss 2.4539\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 1600 Loss 2.3816\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 1700 Loss 2.1042\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 1800 Loss 1.4605\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 1900 Loss 2.4353\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 2000 Loss 2.1901\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 2100 Loss 1.8764\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 2200 Loss 2.4069\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 2300 Loss 2.3222\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 2400 Loss 1.3976\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 2500 Loss 1.6641\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 2600 Loss 1.7454\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 2700 Loss 2.5570\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 2800 Loss 0.9769\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 2900 Loss 1.5994\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 3000 Loss 2.0550\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 3100 Loss 2.3425\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 3200 Loss 1.6102\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 3300 Loss 2.2374\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 3400 Loss 1.2763\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 3500 Loss 1.6444\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 3600 Loss 1.3341\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 3700 Loss 1.5902\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 3800 Loss 2.0642\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 3900 Loss 1.4791\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 4000 Loss 1.6412\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 4100 Loss 1.9346\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 4200 Loss 1.8742\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 4300 Loss 1.7368\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 4400 Loss 2.6232\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 4500 Loss 1.4801\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 4600 Loss 2.0450\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 4700 Loss 2.4528\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 4800 Loss 2.0333\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 4900 Loss 1.5956\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 5000 Loss 1.8646\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 5100 Loss 1.2554\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 5200 Loss 1.5758\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 5300 Loss 1.9764\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 5400 Loss 1.5078\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 5500 Loss 1.7833\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 5600 Loss 1.8694\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 5700 Loss 1.8361\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 5800 Loss 1.6345\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 5900 Loss 1.3410\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 6000 Loss 2.2735\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 6100 Loss 1.9995\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 6200 Loss 1.5713\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 6300 Loss 1.4946\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 6400 Loss 2.0033\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 6500 Loss 2.4749\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 6600 Loss 2.3432\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 6700 Loss 2.0904\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 6800 Loss 2.4296\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 6900 Loss 1.3744\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 7000 Loss 1.5572\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 7100 Loss 1.3179\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 7200 Loss 1.5670\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 7300 Loss 1.3860\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 7400 Loss 1.9046\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 7500 Loss 2.3203\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 7600 Loss 2.1935\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 7700 Loss 1.9890\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 7800 Loss 2.0368\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 7900 Loss 1.4312\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 8000 Loss 2.3419\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 8100 Loss 2.6191\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 8200 Loss 1.4671\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 8300 Loss 1.6046\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 7 Batch 8400 Loss 1.7027\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 100 Loss 1.4364\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 200 Loss 1.3644\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 300 Loss 2.7655\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 400 Loss 2.7143\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 500 Loss 2.3126\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 600 Loss 1.9862\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 700 Loss 1.3885\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 800 Loss 1.4931\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 900 Loss 2.3902\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 1000 Loss 2.0541\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 1100 Loss 1.6049\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 1200 Loss 1.6396\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 1300 Loss 1.6743\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 1400 Loss 1.2098\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 1500 Loss 1.8603\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 1600 Loss 2.0058\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 1700 Loss 1.7182\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 1800 Loss 1.3867\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 1900 Loss 2.7878\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 2000 Loss 1.9377\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 2100 Loss 1.5997\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 2200 Loss 2.2964\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 2300 Loss 2.6571\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 2400 Loss 1.3324\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 2500 Loss 1.6082\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 2600 Loss 1.7338\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 2700 Loss 2.1764\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 2800 Loss 1.0306\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 2900 Loss 1.2449\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 3000 Loss 1.6871\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 3100 Loss 2.5063\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 3200 Loss 1.8006\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 3300 Loss 2.1457\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 3400 Loss 1.4580\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 3500 Loss 1.6532\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 3600 Loss 1.2162\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 3700 Loss 1.5406\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 3800 Loss 1.5279\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 3900 Loss 1.3477\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 4000 Loss 1.5163\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 4100 Loss 1.8725\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 4200 Loss 1.7817\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 4300 Loss 2.8518\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 4400 Loss 2.5728\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 4500 Loss 1.6017\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 4600 Loss 2.0521\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 4700 Loss 1.9207\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 4800 Loss 1.7873\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 4900 Loss 1.6421\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 5000 Loss 2.0842\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 5100 Loss 1.2410\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 8 Batch 5200 Loss 1.9775\n',
# ...
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 3500 Loss 1.4027\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 3600 Loss 0.8910\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 3700 Loss 1.2311\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 3800 Loss 1.2375\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 3900 Loss 1.3046\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 4000 Loss 1.2112\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 4100 Loss 1.7660\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 4200 Loss 1.7507\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 4300 Loss 1.9696\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 4400 Loss 2.4904\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 4500 Loss 1.1676\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 4600 Loss 1.9894\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 4700 Loss 1.7134\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 4800 Loss 1.9308\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 4900 Loss 1.2614\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 5000 Loss 1.7485\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 5100 Loss 1.2430\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 5200 Loss 1.8976\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 5300 Loss 1.8354\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 5400 Loss 1.1218\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 5500 Loss 1.6176\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 5600 Loss 1.6906\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 5700 Loss 1.3286\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 5800 Loss 1.4006\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 5900 Loss 1.7642\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 6000 Loss 1.7415\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 6100 Loss 1.5956\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 6200 Loss 1.4541\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 6300 Loss 1.6950\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 6400 Loss 1.8898\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 6500 Loss 2.1013\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 6600 Loss 2.2081\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 6700 Loss 1.5887\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 6800 Loss 1.8295\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 6900 Loss 1.5293\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 7000 Loss 1.4928\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 7100 Loss 1.0355\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 7200 Loss 1.4590\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 7300 Loss 1.3617\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 7400 Loss 1.2345\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 7500 Loss 1.8323\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 7600 Loss 2.2945\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 7700 Loss 1.9631\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 7800 Loss 1.9489\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 7900 Loss 1.5921\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 8000 Loss 2.0840\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 8100 Loss 2.0459\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 8200 Loss 2.8713\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 8300 Loss 1.3792\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 10 Batch 8400 Loss 1.5141\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 100 Loss 0.8863\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 200 Loss 1.0282\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 300 Loss 1.7160\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 400 Loss 2.2406\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 500 Loss 2.0064\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 600 Loss 1.4153\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 700 Loss 1.3375\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 800 Loss 2.1563\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 900 Loss 1.8842\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 1000 Loss 1.6790\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 1100 Loss 1.2971\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 1200 Loss 1.3811\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 1300 Loss 1.0340\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 1400 Loss 1.2353\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 1500 Loss 1.6139\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 1600 Loss 1.5415\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 1700 Loss 1.2143\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 1800 Loss 1.0053\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 1900 Loss 2.3230\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 2000 Loss 1.7585\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 2100 Loss 1.3996\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 2200 Loss 1.9485\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 2300 Loss 1.9775\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 2400 Loss 1.0970\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 2500 Loss 1.6751\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 2600 Loss 1.3344\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 2700 Loss 1.9377\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 2800 Loss 1.0250\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 2900 Loss 1.0388\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 3000 Loss 1.8390\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 3100 Loss 1.9478\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 3200 Loss 1.2012\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 3300 Loss 2.0285\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 3400 Loss 1.1394\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 3500 Loss 1.5558\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 3600 Loss 1.2790\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 3700 Loss 1.6990\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 3800 Loss 1.5617\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 3900 Loss 1.4439\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 4000 Loss 1.2802\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 4100 Loss 1.6198\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 4200 Loss 1.7397\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 4300 Loss 1.9903\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 4400 Loss 2.3666\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 4500 Loss 1.1129\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 4600 Loss 1.8039\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 4700 Loss 1.7516\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 4800 Loss 1.5653\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 4900 Loss 1.0425\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 5000 Loss 1.7539\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 5100 Loss 1.0934\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 5200 Loss 1.9920\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 5300 Loss 2.0132\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 5400 Loss 1.2277\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 5500 Loss 1.8558\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 5600 Loss 1.5393\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 5700 Loss 1.3983\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 5800 Loss 1.5390\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 5900 Loss 1.3094\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 6000 Loss 2.0587\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 6100 Loss 1.4872\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 6200 Loss 1.4122\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 6300 Loss 1.3772\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 6400 Loss 1.4418\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 6500 Loss 2.1750\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 6600 Loss 1.6846\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 6700 Loss 1.7324\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 6800 Loss 1.6332\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 6900 Loss 2.1273\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 7000 Loss 1.2064\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 7100 Loss 1.2369\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 7200 Loss 1.6318\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 7300 Loss 1.0075\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 7400 Loss 1.2171\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 7500 Loss 2.2984\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 7600 Loss 1.9289\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 7700 Loss 1.8442\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 7800 Loss 2.1992\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 7900 Loss 1.3968\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 8000 Loss 2.1014\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 8100 Loss 1.9419\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 8200 Loss 2.3038\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 8300 Loss 1.4199\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 11 Batch 8400 Loss 1.4745\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 100 Loss 1.1409\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 200 Loss 1.0352\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 300 Loss 1.9507\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 400 Loss 2.4362\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 500 Loss 2.6389\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 600 Loss 1.7816\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 700 Loss 1.3208\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 800 Loss 1.7728\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 900 Loss 2.0456\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 1000 Loss 1.3490\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 1100 Loss 1.3786\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 1200 Loss 1.3392\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 1300 Loss 1.0750\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 1400 Loss 1.1472\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 1500 Loss 1.3809\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 1600 Loss 1.6779\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 1700 Loss 1.3356\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 1800 Loss 1.0196\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 1900 Loss 1.8837\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 2000 Loss 2.0952\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 2100 Loss 1.3204\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 2200 Loss 1.4368\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 2300 Loss 2.4409\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 2400 Loss 1.3127\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 2500 Loss 1.7495\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 2600 Loss 1.7869\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 2700 Loss 2.0349\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 2800 Loss 1.0316\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 2900 Loss 0.7808\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 3000 Loss 1.7707\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 3100 Loss 1.8992\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 3200 Loss 1.1820\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 3300 Loss 2.1295\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 3400 Loss 1.3877\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 3500 Loss 1.5284\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 3600 Loss 0.8657\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 3700 Loss 1.0212\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 3800 Loss 1.3507\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 3900 Loss 1.2319\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 4000 Loss 1.1180\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 4100 Loss 1.8014\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 4200 Loss 1.4517\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 4300 Loss 1.4202\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 4400 Loss 2.2941\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 4500 Loss 1.3473\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 4600 Loss 1.8912\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 4700 Loss 1.4530\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 4800 Loss 1.6584\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 4900 Loss 1.5402\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 5000 Loss 1.9222\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 5100 Loss 1.1607\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 5200 Loss 1.7058\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 5300 Loss 2.0389\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 5400 Loss 1.1941\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 5500 Loss 1.6607\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 5600 Loss 1.7587\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 5700 Loss 1.2217\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 5800 Loss 1.3095\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 5900 Loss 1.0390\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 6000 Loss 1.2440\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 6100 Loss 1.3542\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 6200 Loss 1.3769\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 6300 Loss 1.6159\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 6400 Loss 1.5358\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 6500 Loss 2.1524\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 6600 Loss 1.7350\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 6700 Loss 1.7689\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 6800 Loss 1.6242\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 6900 Loss 1.6468\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 7000 Loss 1.1348\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 7100 Loss 0.9407\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 7200 Loss 1.3564\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 7300 Loss 0.9138\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 7400 Loss 1.5342\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 7500 Loss 1.9782\n',
#  ' ./checkpoints/train/2020-03-04 16:30 Epoch 12 Batch 7600 Loss 1.9426\n',
#  ...]

# %%
loss = [float(x[x.find('Loss') + 5 :].strip()) for x in log]

plt.figure(figsize=(13,13))
plt.plot(loss);
