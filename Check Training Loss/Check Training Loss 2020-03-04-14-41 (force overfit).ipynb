# %% [markdown]
# # Plot Training Loss

# %%
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ### Note
#
# trying to overfit

# %%
training_time = "2020-03-04 14:41"

# %%
config = open("../checkpoints/train/{}/config.txt".format(training_time), "r").read()
config = str(config.replace("'", '"').replace("True", 'true'))
config = json.loads(config)
config
# Out:
# {'rnn_units': 512,
#  'rnn_type': 'LSTM',
#  'tokenizer': 'BERT',
#  'word_embedding': 'BERT',
#  'vocab_size': 1000,
#  'combine_strategy': 'merge',
#  'combine_layer': 'concat',
#  'image_context_size': 256,
#  'word_embedding_dim': 256,
#  'batch_size': 32,
#  'data_size': 3000,
#  'use_mapping': True,
#  'learning_rate': 0.001,
#  'max_caption_length': 25,
#  'image_feature_extractor': 'xception'}

# %%
log = open("../checkpoints/train/{}/log.txt".format(training_time), "r").readlines()
log
# Out:
# [' ./checkpoints/train/2020-03-04 14:41 Epoch 1 Batch 100 Loss 4.8734\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 1 Batch 200 Loss 4.5254\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 1 Batch 300 Loss 4.5315\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 1 Batch 400 Loss 4.4415\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 1 Batch 500 Loss 4.9879\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 1 Batch 600 Loss 4.9900\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 1 Batch 700 Loss 3.1610\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 1 Batch 800 Loss 3.3720\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 2 Batch 100 Loss 4.1299\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 2 Batch 200 Loss 3.4642\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 2 Batch 300 Loss 3.5371\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 2 Batch 400 Loss 3.8009\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 2 Batch 500 Loss 3.6367\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 2 Batch 600 Loss 4.3679\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 2 Batch 700 Loss 2.7236\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 2 Batch 800 Loss 2.7452\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 3 Batch 100 Loss 3.7365\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 3 Batch 200 Loss 2.8731\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 3 Batch 300 Loss 3.1976\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 3 Batch 400 Loss 3.5274\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 3 Batch 500 Loss 3.1524\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 3 Batch 600 Loss 3.7397\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 3 Batch 700 Loss 2.2588\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 3 Batch 800 Loss 2.3556\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 4 Batch 100 Loss 2.8371\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 4 Batch 200 Loss 2.6829\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 4 Batch 300 Loss 2.8194\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 4 Batch 400 Loss 3.2272\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 4 Batch 500 Loss 2.7023\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 4 Batch 600 Loss 3.3612\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 4 Batch 700 Loss 1.9556\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 4 Batch 800 Loss 1.9771\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 5 Batch 100 Loss 2.6057\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 5 Batch 200 Loss 2.5261\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 5 Batch 300 Loss 2.8701\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 5 Batch 400 Loss 2.8263\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 5 Batch 500 Loss 2.4675\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 5 Batch 600 Loss 3.1348\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 5 Batch 700 Loss 1.8624\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 5 Batch 800 Loss 1.8591\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 6 Batch 100 Loss 2.3572\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 6 Batch 200 Loss 2.0844\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 6 Batch 300 Loss 2.1525\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 6 Batch 400 Loss 2.7027\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 6 Batch 500 Loss 2.3998\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 6 Batch 600 Loss 2.6769\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 6 Batch 700 Loss 1.8603\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 6 Batch 800 Loss 1.4945\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 7 Batch 100 Loss 1.9744\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 7 Batch 200 Loss 1.9616\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 7 Batch 300 Loss 2.0794\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 7 Batch 400 Loss 2.3162\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 7 Batch 500 Loss 1.9638\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 7 Batch 600 Loss 2.2501\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 7 Batch 700 Loss 1.5470\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 7 Batch 800 Loss 1.4369\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 8 Batch 100 Loss 1.7962\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 8 Batch 200 Loss 1.7639\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 8 Batch 300 Loss 2.1419\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 8 Batch 400 Loss 2.2943\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 8 Batch 500 Loss 2.0417\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 8 Batch 600 Loss 2.2425\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 8 Batch 700 Loss 1.6039\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 8 Batch 800 Loss 1.4309\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 9 Batch 100 Loss 1.6017\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 9 Batch 200 Loss 1.5461\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 9 Batch 300 Loss 1.6034\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 9 Batch 400 Loss 1.6193\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 9 Batch 500 Loss 2.0932\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 9 Batch 600 Loss 1.8702\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 9 Batch 700 Loss 1.3902\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 9 Batch 800 Loss 1.0547\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 10 Batch 100 Loss 2.0700\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 10 Batch 200 Loss 1.4012\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 10 Batch 300 Loss 1.2906\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 10 Batch 400 Loss 1.4855\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 10 Batch 500 Loss 1.4766\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 10 Batch 600 Loss 1.8646\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 10 Batch 700 Loss 2.3484\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 10 Batch 800 Loss 0.9972\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 11 Batch 100 Loss 1.6407\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 11 Batch 200 Loss 1.4597\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 11 Batch 300 Loss 1.3811\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 11 Batch 400 Loss 1.3717\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 11 Batch 500 Loss 1.5237\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 11 Batch 600 Loss 1.5979\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 11 Batch 700 Loss 1.6993\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 11 Batch 800 Loss 0.9333\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 12 Batch 100 Loss 1.1294\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 12 Batch 200 Loss 1.3222\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 12 Batch 300 Loss 1.0633\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 12 Batch 400 Loss 1.4285\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 12 Batch 500 Loss 1.6472\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 12 Batch 600 Loss 1.3989\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 12 Batch 700 Loss 0.9338\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 12 Batch 800 Loss 0.9675\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 13 Batch 100 Loss 1.1215\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 13 Batch 200 Loss 1.2695\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 13 Batch 300 Loss 1.0065\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 13 Batch 400 Loss 1.5296\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 13 Batch 500 Loss 1.5593\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 13 Batch 600 Loss 1.1727\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 13 Batch 700 Loss 1.0884\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 13 Batch 800 Loss 1.0543\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 14 Batch 100 Loss 1.0542\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 14 Batch 200 Loss 0.7903\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 14 Batch 300 Loss 0.8164\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 14 Batch 400 Loss 1.2978\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 14 Batch 500 Loss 1.1352\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 14 Batch 600 Loss 1.4276\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 14 Batch 700 Loss 1.1970\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 14 Batch 800 Loss 0.7266\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 15 Batch 100 Loss 1.0399\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 15 Batch 200 Loss 0.8620\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 15 Batch 300 Loss 1.0851\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 15 Batch 400 Loss 1.6461\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 15 Batch 500 Loss 1.6142\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 15 Batch 600 Loss 1.2253\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 15 Batch 700 Loss 0.5860\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 15 Batch 800 Loss 0.7686\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 16 Batch 100 Loss 0.8279\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 16 Batch 200 Loss 0.7160\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 16 Batch 300 Loss 0.6993\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 16 Batch 400 Loss 1.4308\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 16 Batch 500 Loss 1.3497\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 16 Batch 600 Loss 1.0226\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 16 Batch 700 Loss 0.6958\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 16 Batch 800 Loss 0.5571\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 17 Batch 100 Loss 1.2144\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 17 Batch 200 Loss 0.7898\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 17 Batch 300 Loss 0.6998\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 17 Batch 400 Loss 1.1474\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 17 Batch 500 Loss 0.9245\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 17 Batch 600 Loss 0.8881\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 17 Batch 700 Loss 0.5949\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 17 Batch 800 Loss 0.4930\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 18 Batch 100 Loss 0.6674\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 18 Batch 200 Loss 0.6465\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 18 Batch 300 Loss 0.7595\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 18 Batch 400 Loss 0.9586\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 18 Batch 500 Loss 0.6992\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 18 Batch 600 Loss 0.9897\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 18 Batch 700 Loss 1.0542\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 18 Batch 800 Loss 0.4834\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 19 Batch 100 Loss 0.7170\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 19 Batch 200 Loss 0.9902\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 19 Batch 300 Loss 0.8144\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 19 Batch 400 Loss 1.0779\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 19 Batch 500 Loss 0.7855\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 19 Batch 600 Loss 0.7464\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 19 Batch 700 Loss 0.5005\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 19 Batch 800 Loss 0.5063\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 20 Batch 100 Loss 0.4315\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 20 Batch 200 Loss 0.7842\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 20 Batch 300 Loss 0.6220\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 20 Batch 400 Loss 0.8046\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 20 Batch 500 Loss 0.8942\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 20 Batch 600 Loss 1.2432\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 20 Batch 700 Loss 0.6539\n',
#  ' ./checkpoints/train/2020-03-04 14:41 Epoch 20 Batch 800 Loss 0.4999\n']

# %%
loss = [float(x[x.find('Loss') + 5 :].strip()) for x in log]

plt.figure(figsize=(13,13))
plt.plot(loss);
