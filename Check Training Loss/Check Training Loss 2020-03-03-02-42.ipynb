# %% [markdown]
# # Plot Training Loss

# %%
import matplotlib.pyplot as plt
import json

# %%
training_time = "2020-03-03 02:42"

# %%
config = open("./checkpoints/train/{}/config.txt".format(training_time), "r").read()
config = str(config.replace("'", '"').replace("True", 'true'))
config = json.loads(config)
config
# Out:
# {'rnn_units': 256,
#  'rnn_type': 'LSTM',
#  'tokenizer': 'BERT',
#  'word_embedding': 'BERT',
#  'vocab_size': 3000,
#  'combine_strategy': 'merge',
#  'combine_layer': 'concat',
#  'image_context_size': 256,
#  'word_embedding_dim': 256,
#  'batch_size': 32,
#  'data_size': 30000,
#  'use_mapping': True,
#  'learning_rate': 0.001,
#  'max_caption_length': 25,
#  'image_feature_extractor': 'xception'}

# %%
log = open("./checkpoints/train/{}/log.txt".format(training_time), "r").readlines()
log
# Out:
# [' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 500 Loss 4.4219\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 1000 Loss 3.7905\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 1500 Loss 4.8601\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 2000 Loss 4.1182\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 2500 Loss 3.0522\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 3000 Loss 3.8747\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 3500 Loss 3.4725\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 4000 Loss 3.7630\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 4500 Loss 2.7688\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 5000 Loss 3.1353\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 5500 Loss 3.3390\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 6000 Loss 4.4240\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 6500 Loss 4.1726\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 7000 Loss 3.0896\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 7500 Loss 3.2917\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 1 Batch 8000 Loss 3.6541\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 500 Loss 3.1564\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 1000 Loss 2.8805\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 1500 Loss 3.9252\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 2000 Loss 3.3682\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 2500 Loss 2.6051\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 3000 Loss 3.3856\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 3500 Loss 3.3628\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 4000 Loss 3.2870\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 4500 Loss 2.4248\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 5000 Loss 2.6631\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 5500 Loss 2.8142\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 6000 Loss 3.9332\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 6500 Loss 3.9483\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 7000 Loss 2.7775\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 7500 Loss 3.1772\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 2 Batch 8000 Loss 3.1787\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 500 Loss 3.0309\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 1000 Loss 2.6633\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 1500 Loss 3.5000\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 2000 Loss 3.1183\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 2500 Loss 2.5919\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 3000 Loss 3.0327\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 3500 Loss 3.2224\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 4000 Loss 3.0309\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 4500 Loss 2.2958\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 5000 Loss 2.4782\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 5500 Loss 2.6425\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 6000 Loss 3.5877\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 6500 Loss 3.6212\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 7000 Loss 2.6047\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 7500 Loss 2.9492\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 3 Batch 8000 Loss 2.9029\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 500 Loss 2.9823\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 1000 Loss 2.5552\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 1500 Loss 3.1452\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 2000 Loss 2.8477\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 2500 Loss 2.4650\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 3000 Loss 2.7340\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 3500 Loss 3.0047\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 4000 Loss 2.7525\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 4500 Loss 2.1785\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 5000 Loss 2.3075\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 5500 Loss 2.5884\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 6000 Loss 3.3491\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 6500 Loss 3.2624\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 7000 Loss 2.4339\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 7500 Loss 2.7571\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 4 Batch 8000 Loss 2.7408\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 500 Loss 2.8318\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 1000 Loss 2.4216\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 1500 Loss 2.8260\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 2000 Loss 2.5017\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 2500 Loss 2.3782\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 3000 Loss 2.4401\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 3500 Loss 2.9024\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 4000 Loss 2.4676\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 4500 Loss 2.1342\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 5000 Loss 2.2926\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 5500 Loss 2.2953\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 6000 Loss 3.2287\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 6500 Loss 3.0179\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 7000 Loss 2.2653\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 7500 Loss 2.5282\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 5 Batch 8000 Loss 2.6074\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 500 Loss 2.7472\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 1000 Loss 2.2651\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 1500 Loss 2.7788\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 2000 Loss 2.1090\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 2500 Loss 2.3476\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 3000 Loss 2.1823\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 3500 Loss 2.7468\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 4000 Loss 2.3662\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 4500 Loss 2.0771\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 5000 Loss 2.1593\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 5500 Loss 1.9963\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 6000 Loss 3.0439\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 6500 Loss 2.7438\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 7000 Loss 2.1434\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 7500 Loss 2.2498\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 6 Batch 8000 Loss 2.6287\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 500 Loss 2.8093\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 1000 Loss 2.1310\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 1500 Loss 2.7272\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 2000 Loss 1.9872\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 2500 Loss 2.1198\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 3000 Loss 2.1295\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 3500 Loss 2.6486\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 4000 Loss 2.3008\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 4500 Loss 1.8747\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 5000 Loss 1.9131\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 5500 Loss 1.8040\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 6000 Loss 2.8039\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 6500 Loss 2.4064\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 7000 Loss 2.0263\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 7500 Loss 2.1097\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 7 Batch 8000 Loss 2.4928\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 500 Loss 2.6175\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 1000 Loss 1.9951\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 1500 Loss 2.4267\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 2000 Loss 1.9729\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 2500 Loss 1.9803\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 3000 Loss 2.1062\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 3500 Loss 2.6335\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 4000 Loss 2.0877\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 4500 Loss 1.9870\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 5000 Loss 2.0207\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 5500 Loss 1.8378\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 6000 Loss 2.6372\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 6500 Loss 2.2383\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 7000 Loss 1.8966\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 7500 Loss 2.0175\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 8 Batch 8000 Loss 2.5974\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 500 Loss 2.5692\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 1000 Loss 2.0374\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 1500 Loss 2.3419\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 2000 Loss 1.9364\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 2500 Loss 1.9022\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 3000 Loss 1.9385\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 3500 Loss 2.8682\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 4000 Loss 1.9455\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 4500 Loss 1.6691\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 5000 Loss 1.8620\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 5500 Loss 1.5683\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 6000 Loss 2.4192\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 6500 Loss 2.1524\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 7000 Loss 1.8542\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 7500 Loss 1.9113\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 9 Batch 8000 Loss 2.4872\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 500 Loss 2.4776\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 1000 Loss 1.7982\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 1500 Loss 2.2614\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 2000 Loss 1.6979\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 2500 Loss 1.8739\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 3000 Loss 2.0507\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 3500 Loss 2.4231\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 4000 Loss 1.8457\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 4500 Loss 1.7127\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 5000 Loss 1.8126\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 5500 Loss 1.8007\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 6000 Loss 2.2871\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 6500 Loss 1.8479\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 7000 Loss 1.7659\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 7500 Loss 1.8967\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 10 Batch 8000 Loss 2.4607\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 500 Loss 2.3838\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 1000 Loss 1.7870\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 1500 Loss 1.7914\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 2000 Loss 1.5740\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 2500 Loss 1.7888\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 3000 Loss 1.5780\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 3500 Loss 2.0477\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 4000 Loss 1.9850\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 4500 Loss 1.5319\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 5000 Loss 1.8808\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 5500 Loss 1.6368\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 6000 Loss 2.3854\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 6500 Loss 1.6934\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 7000 Loss 1.6766\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 7500 Loss 1.7679\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 11 Batch 8000 Loss 2.4108\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 500 Loss 2.1168\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 1000 Loss 1.7564\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 1500 Loss 2.1192\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 2000 Loss 1.8393\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 2500 Loss 1.8239\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 3000 Loss 1.5992\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 3500 Loss 2.0211\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 4000 Loss 1.6703\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 4500 Loss 1.7439\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 5000 Loss 1.9276\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 5500 Loss 1.7294\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 6000 Loss 2.0792\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 6500 Loss 1.6709\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 7000 Loss 1.6407\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 7500 Loss 1.6592\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 12 Batch 8000 Loss 2.3879\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 500 Loss 2.1664\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 1000 Loss 1.5929\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 1500 Loss 1.9223\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 2000 Loss 1.4040\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 2500 Loss 1.7511\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 3000 Loss 1.6934\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 3500 Loss 2.0157\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 4000 Loss 1.8140\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 4500 Loss 1.4793\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 5000 Loss 1.9712\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 5500 Loss 1.4768\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 6000 Loss 2.1849\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 6500 Loss 1.4291\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 7000 Loss 1.5169\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 7500 Loss 1.3849\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 13 Batch 8000 Loss 2.1224\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 500 Loss 1.8989\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 1000 Loss 1.6261\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 1500 Loss 1.8549\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 2000 Loss 1.5001\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 2500 Loss 1.7970\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 3000 Loss 1.4051\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 3500 Loss 1.9140\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 4000 Loss 1.8444\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 4500 Loss 1.4603\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 5000 Loss 1.9871\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 5500 Loss 1.3644\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 6000 Loss 2.0942\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 6500 Loss 1.6668\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 7000 Loss 1.4896\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 7500 Loss 1.4300\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 14 Batch 8000 Loss 2.1824\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 500 Loss 1.8457\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 1000 Loss 1.3219\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 1500 Loss 1.8424\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 2000 Loss 1.4181\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 2500 Loss 1.6639\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 3000 Loss 1.3640\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 3500 Loss 2.1843\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 4000 Loss 1.7513\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 4500 Loss 1.3367\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 5000 Loss 1.8735\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 5500 Loss 1.6911\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 6000 Loss 1.9450\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 6500 Loss 1.2412\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 7000 Loss 1.2677\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 7500 Loss 1.4959\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 15 Batch 8000 Loss 1.9798\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 500 Loss 1.9686\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 1000 Loss 1.3340\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 1500 Loss 1.7758\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 2000 Loss 1.5968\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 2500 Loss 1.8140\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 3000 Loss 1.4108\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 3500 Loss 2.0366\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 4000 Loss 1.7232\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 4500 Loss 1.3524\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 5000 Loss 1.5680\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 5500 Loss 1.1061\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 6000 Loss 1.9317\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 6500 Loss 1.3679\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 7000 Loss 1.3688\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 7500 Loss 1.2977\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 16 Batch 8000 Loss 1.8767\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 500 Loss 1.5586\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 1000 Loss 1.4039\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 1500 Loss 1.6794\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 2000 Loss 1.2013\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 2500 Loss 1.6505\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 3000 Loss 1.3310\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 3500 Loss 1.9899\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 4000 Loss 1.6007\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 4500 Loss 1.2937\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 5000 Loss 1.6695\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 5500 Loss 1.2970\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 6000 Loss 1.6527\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 6500 Loss 1.3235\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 7000 Loss 1.4165\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 7500 Loss 1.2659\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 17 Batch 8000 Loss 2.0351\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 500 Loss 1.7716\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 1000 Loss 1.2633\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 1500 Loss 1.4087\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 2000 Loss 1.1567\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 2500 Loss 1.6085\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 3000 Loss 1.2722\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 3500 Loss 1.8105\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 4000 Loss 1.4797\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 4500 Loss 1.3856\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 5000 Loss 1.6644\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 5500 Loss 1.2271\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 6000 Loss 1.7772\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 6500 Loss 1.1750\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 7000 Loss 1.2331\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 7500 Loss 1.1316\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 18 Batch 8000 Loss 1.7232\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 500 Loss 1.6899\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 1000 Loss 1.3282\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 1500 Loss 1.5293\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 2000 Loss 1.4453\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 2500 Loss 1.6087\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 3000 Loss 0.9687\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 3500 Loss 1.8902\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 4000 Loss 1.6864\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 4500 Loss 1.3602\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 5000 Loss 1.6129\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 5500 Loss 1.3050\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 6000 Loss 1.6204\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 6500 Loss 1.2282\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 7000 Loss 1.3510\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 7500 Loss 1.3873\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 19 Batch 8000 Loss 1.7166\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 500 Loss 1.5501\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 1000 Loss 1.1761\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 1500 Loss 1.6652\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 2000 Loss 1.0871\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 2500 Loss 1.7755\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 3000 Loss 1.0862\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 3500 Loss 1.9917\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 4000 Loss 1.3043\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 4500 Loss 1.3954\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 5000 Loss 1.5540\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 5500 Loss 1.0924\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 6000 Loss 1.3915\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 6500 Loss 1.1476\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 7000 Loss 1.0940\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 7500 Loss 1.2100\n',
#  ' ./checkpoints/train/2020-03-03 02:42 Epoch 20 Batch 8000 Loss 1.6933\n']

# %%
loss = [float(x[x.find('Loss') + 5 :].strip()) for x in log]

plt.figure(figsize=(13,13))
plt.plot(loss);
