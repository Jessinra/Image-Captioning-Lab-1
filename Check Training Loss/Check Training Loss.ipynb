# %% [markdown]
# # Plot Training Loss

# %%
import matplotlib.pyplot as plt
import json

# %%
training_time = "2020-03-02 03:53"

# %%
config = open("../checkpoints/train/{}/config.txt".format(training_time), "r").read()
config = str(config.replace("'", '"').replace("True", 'true'))
config = json.loads(config)
config
# Out:
# {'rnn_units': 512,
#  'rnn_type': 'LSTM',
#  'tokenizer': 'BERT',
#  'word_embedding': 'BERT',
#  'vocab_size': 3000,
#  'combine_strategy': 'merge',
#  'combine_layer': 'concat',
#  'image_context_size': 256,
#  'word_embedding_dim': 256,
#  'batch_size': 32,
#  'data_size': 30000,
#  'use_mapping': True,
#  'learning_rate': 0.001}

# %%
log = open("../checkpoints/train/{}/log.txt".format(training_time), "r").readlines()
log
# Out:
# ['./checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 50 Loss 63.2271\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 100 Loss 60.5953\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 150 Loss 57.7274\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 200 Loss 65.9248\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 250 Loss 60.5348\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 300 Loss 60.9146\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 350 Loss 60.4133\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 400 Loss 55.3550\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 450 Loss 56.6056\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 500 Loss 58.9202\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 550 Loss 53.5401\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 600 Loss 59.2820\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 1 Batch 650 Loss 56.4276\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 50 Loss 53.2044\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 100 Loss 54.0406\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 150 Loss 53.2353\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 200 Loss 61.0659\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 250 Loss 56.6838\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 300 Loss 56.9754\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 350 Loss 56.5464\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 400 Loss 52.7009\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 450 Loss 53.1948\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 500 Loss 56.8964\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 550 Loss 51.8431\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 600 Loss 57.5741\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 2 Batch 650 Loss 54.2143\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 50 Loss 51.0599\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 100 Loss 51.9824\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 150 Loss 51.8096\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 200 Loss 58.4888\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 250 Loss 54.3983\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 300 Loss 55.8996\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 350 Loss 55.5005\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 400 Loss 50.9314\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 450 Loss 51.1403\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 500 Loss 55.0875\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 550 Loss 50.4926\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 600 Loss 55.8826\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 3 Batch 650 Loss 52.7818\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 50 Loss 49.3576\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 100 Loss 51.4825\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 150 Loss 49.8702\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 200 Loss 57.4126\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 250 Loss 53.3170\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 300 Loss 55.5376\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 350 Loss 53.4136\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 400 Loss 49.3370\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 450 Loss 49.5511\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 500 Loss 54.1307\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 550 Loss 48.8606\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 600 Loss 54.4223\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 4 Batch 650 Loss 51.2260\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 50 Loss 48.2858\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 100 Loss 50.4678\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 150 Loss 49.5762\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 200 Loss 55.7429\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 250 Loss 52.3121\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 300 Loss 53.7171\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 350 Loss 53.3934\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 400 Loss 48.3182\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 450 Loss 48.7664\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 500 Loss 52.4880\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 550 Loss 47.3021\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 600 Loss 53.7535\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 5 Batch 650 Loss 50.2892\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 50 Loss 47.5234\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 100 Loss 48.8758\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 150 Loss 48.2913\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 200 Loss 54.7995\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 250 Loss 52.9001\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 300 Loss 52.3027\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 350 Loss 51.2427\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 400 Loss 47.6994\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 450 Loss 47.8780\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 500 Loss 52.3354\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 550 Loss 46.8993\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 600 Loss 53.6703\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 6 Batch 650 Loss 48.7796\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 50 Loss 47.3980\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 100 Loss 47.5121\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 150 Loss 47.3852\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 200 Loss 53.5128\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 250 Loss 51.0210\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 300 Loss 51.0542\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 350 Loss 48.6443\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 400 Loss 46.3498\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 450 Loss 46.7860\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 500 Loss 50.6443\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 550 Loss 46.8884\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 600 Loss 52.0653\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 7 Batch 650 Loss 48.0597\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 50 Loss 46.4993\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 100 Loss 46.2785\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 150 Loss 46.5598\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 200 Loss 52.6742\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 250 Loss 50.2130\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 300 Loss 50.2237\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 350 Loss 47.6967\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 400 Loss 45.8110\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 450 Loss 46.2904\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 500 Loss 49.6759\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 550 Loss 45.3979\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 600 Loss 49.9539\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 8 Batch 650 Loss 47.6939\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 50 Loss 45.5688\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 100 Loss 45.8837\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 150 Loss 46.9569\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 200 Loss 51.1291\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 250 Loss 49.1484\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 300 Loss 50.2209\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 350 Loss 47.8242\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 400 Loss 44.8275\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 450 Loss 46.2805\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 500 Loss 48.7740\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 550 Loss 45.3596\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 600 Loss 48.9646\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 9 Batch 650 Loss 46.2858\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 10 Batch 50 Loss 45.8135\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 10 Batch 100 Loss 45.8096\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 10 Batch 150 Loss 46.0678\n',
#  './checkpoints/train/2020-03-02 03:53 Epoch 10 Batch 200 Loss 51.2203\n']

# %%
loss = [float(x[x.find('Loss') + 5 :].strip()) for x in log]

plt.figure(figsize=(13,13))
plt.plot(loss);
