# %% [markdown]
# # Plot Training Loss

# %%
import matplotlib.pyplot as plt
import json

# %%
training_time = "2020-03-03 10:10"

# %%
config = open("../checkpoints/train/{}/config.txt".format(training_time), "r").read()
config = str(config.replace("'", '"').replace("True", 'true'))
config = json.loads(config)
config
# Out:
# {'rnn_units': 512,
#  'rnn_type': 'LSTM',
#  'tokenizer': 'BERT',
#  'word_embedding': 'BERT',
#  'vocab_size': 3000,
#  'combine_strategy': 'merge',
#  'combine_layer': 'concat',
#  'image_context_size': 256,
#  'word_embedding_dim': 256,
#  'batch_size': 32,
#  'data_size': 30000,
#  'use_mapping': True,
#  'learning_rate': 0.001,
#  'max_caption_length': 25,
#  'image_feature_extractor': 'xception'}

# %%
log = open("../checkpoints/train/{}/log.txt".format(training_time), "r").readlines()
log
# Out:
# [' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 500 Loss 4.5069\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 1000 Loss 3.8984\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 1500 Loss 4.8978\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 2000 Loss 4.4403\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 2500 Loss 3.2259\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 3000 Loss 3.8432\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 3500 Loss 3.4661\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 4000 Loss 3.9075\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 4500 Loss 2.8775\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 5000 Loss 3.3993\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 5500 Loss 3.4631\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 6000 Loss 4.5884\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 6500 Loss 4.1528\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 7000 Loss 3.2242\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 7500 Loss 3.4202\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 1 Batch 8000 Loss 3.6216\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 500 Loss 3.1864\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 1000 Loss 3.0088\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 1500 Loss 3.9349\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 2000 Loss 3.5495\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 2500 Loss 2.5982\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 3000 Loss 3.3202\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 3500 Loss 3.1780\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 4000 Loss 3.2846\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 4500 Loss 2.5088\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 5000 Loss 2.8307\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 5500 Loss 2.9839\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 6000 Loss 4.0529\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 6500 Loss 3.9684\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 7000 Loss 2.8454\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 7500 Loss 3.1196\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 2 Batch 8000 Loss 3.2227\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 500 Loss 3.0580\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 1000 Loss 2.6135\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 1500 Loss 3.3808\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 2000 Loss 3.0730\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 2500 Loss 2.5069\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 3000 Loss 3.1040\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 3500 Loss 3.0409\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 4000 Loss 2.9160\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 4500 Loss 2.3097\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 5000 Loss 2.7319\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 5500 Loss 2.7255\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 6000 Loss 3.7133\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 6500 Loss 3.7572\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 7000 Loss 2.5368\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 7500 Loss 2.9622\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 3 Batch 8000 Loss 3.1327\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 500 Loss 2.9840\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 1000 Loss 2.5851\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 1500 Loss 3.0823\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 2000 Loss 2.7574\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 2500 Loss 2.3172\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 3000 Loss 3.0210\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 3500 Loss 2.8689\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 4000 Loss 2.6810\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 4500 Loss 2.1582\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 5000 Loss 2.5852\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 5500 Loss 2.6677\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 6000 Loss 3.5871\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 6500 Loss 3.5457\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 7000 Loss 2.5300\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 7500 Loss 2.6327\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 4 Batch 8000 Loss 2.9473\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 500 Loss 2.7818\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 1000 Loss 2.4738\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 1500 Loss 3.0404\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 2000 Loss 2.4791\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 2500 Loss 2.2260\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 3000 Loss 2.7827\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 3500 Loss 2.6554\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 4000 Loss 2.5593\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 4500 Loss 2.0665\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 5000 Loss 2.2984\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 5500 Loss 2.4572\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 6000 Loss 3.4836\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 6500 Loss 3.3514\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 7000 Loss 2.3924\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 7500 Loss 2.6350\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 5 Batch 8000 Loss 2.8737\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 500 Loss 2.7247\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 1000 Loss 2.4369\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 1500 Loss 2.8191\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 2000 Loss 2.3379\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 2500 Loss 2.2125\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 3000 Loss 2.4228\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 3500 Loss 2.5111\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 4000 Loss 2.3235\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 4500 Loss 1.9744\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 5000 Loss 2.1449\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 5500 Loss 2.4823\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 6000 Loss 3.2816\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 6500 Loss 3.1396\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 7000 Loss 2.3588\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 7500 Loss 2.2826\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 6 Batch 8000 Loss 2.6201\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 500 Loss 2.4886\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 1000 Loss 2.3339\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 1500 Loss 2.8898\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 2000 Loss 2.0274\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 2500 Loss 2.1831\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 3000 Loss 2.1266\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 3500 Loss 2.4991\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 4000 Loss 2.2387\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 4500 Loss 1.7981\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 5000 Loss 2.1279\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 5500 Loss 2.2605\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 6000 Loss 3.1321\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 6500 Loss 3.2362\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 7000 Loss 2.1352\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 7500 Loss 2.2841\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 7 Batch 8000 Loss 2.4413\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 500 Loss 2.5752\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 1000 Loss 2.2813\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 1500 Loss 2.4889\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 2000 Loss 1.9715\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 2500 Loss 2.1667\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 3000 Loss 1.9984\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 3500 Loss 2.2155\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 4000 Loss 2.0303\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 4500 Loss 1.6659\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 5000 Loss 2.1975\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 5500 Loss 2.1189\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 6000 Loss 2.9127\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 6500 Loss 3.1078\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 7000 Loss 2.1641\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 7500 Loss 2.2702\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 8 Batch 8000 Loss 2.6468\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 500 Loss 2.2664\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 1000 Loss 2.1204\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 1500 Loss 2.2749\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 2000 Loss 1.7921\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 2500 Loss 2.0993\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 3000 Loss 1.8676\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 3500 Loss 2.1282\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 4000 Loss 1.9662\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 4500 Loss 1.7362\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 5000 Loss 2.0876\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 5500 Loss 2.2551\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 6000 Loss 2.6270\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 6500 Loss 3.2014\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 7000 Loss 1.9848\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 7500 Loss 2.1574\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 9 Batch 8000 Loss 2.1680\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 500 Loss 2.1934\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 1000 Loss 2.1479\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 1500 Loss 2.4390\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 2000 Loss 1.6459\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 2500 Loss 2.0907\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 3000 Loss 1.6278\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 3500 Loss 2.1051\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 4000 Loss 1.7644\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 4500 Loss 1.6060\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 5000 Loss 2.2685\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 5500 Loss 2.1172\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 6000 Loss 2.5096\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 6500 Loss 2.8012\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 7000 Loss 2.0682\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 7500 Loss 2.0069\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 10 Batch 8000 Loss 2.1069\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 500 Loss 2.3150\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 1000 Loss 1.9182\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 1500 Loss 2.2895\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 2000 Loss 1.8864\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 2500 Loss 1.8466\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 3000 Loss 1.5706\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 3500 Loss 2.3032\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 4000 Loss 1.7398\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 4500 Loss 1.6496\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 5000 Loss 1.8217\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 5500 Loss 2.0488\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 6000 Loss 2.4184\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 6500 Loss 2.6899\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 7000 Loss 1.9634\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 7500 Loss 1.6637\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 11 Batch 8000 Loss 2.3741\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 500 Loss 1.9775\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 1000 Loss 2.0248\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 1500 Loss 2.4888\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 2000 Loss 1.6614\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 2500 Loss 1.6319\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 3000 Loss 1.3500\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 3500 Loss 1.9875\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 4000 Loss 1.4114\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 4500 Loss 1.4786\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 5000 Loss 2.0092\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 5500 Loss 2.0534\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 6000 Loss 2.1121\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 6500 Loss 2.4646\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 7000 Loss 1.7088\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 7500 Loss 1.8354\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 12 Batch 8000 Loss 2.1084\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 500 Loss 1.9845\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 1000 Loss 1.5894\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 1500 Loss 2.1946\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 2000 Loss 1.4695\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 2500 Loss 1.6734\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 3000 Loss 1.3372\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 3500 Loss 1.8551\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 4000 Loss 1.4568\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 4500 Loss 1.3046\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 5000 Loss 1.5544\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 5500 Loss 1.6726\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 6000 Loss 2.0851\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 6500 Loss 2.1065\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 7000 Loss 1.9056\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 7500 Loss 1.6403\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 13 Batch 8000 Loss 1.8920\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 500 Loss 1.9899\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 1000 Loss 1.9292\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 1500 Loss 2.0055\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 2000 Loss 1.6096\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 2500 Loss 1.5213\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 3000 Loss 1.1068\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 3500 Loss 1.7494\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 4000 Loss 1.3003\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 4500 Loss 1.4502\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 5000 Loss 1.4704\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 5500 Loss 1.6910\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 6000 Loss 1.9764\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 6500 Loss 2.1442\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 7000 Loss 1.6747\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 7500 Loss 1.6214\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 14 Batch 8000 Loss 1.7817\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 500 Loss 1.9627\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 1000 Loss 1.5834\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 1500 Loss 2.3007\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 2000 Loss 1.5721\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 2500 Loss 1.5635\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 3000 Loss 1.0938\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 3500 Loss 1.8188\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 4000 Loss 1.3095\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 4500 Loss 1.3972\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 5000 Loss 1.6247\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 5500 Loss 1.9094\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 6000 Loss 2.0621\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 6500 Loss 1.9268\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 7000 Loss 1.5080\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 7500 Loss 1.8580\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 15 Batch 8000 Loss 1.6082\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 500 Loss 1.9116\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 1000 Loss 1.5633\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 1500 Loss 1.7682\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 2000 Loss 1.5027\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 2500 Loss 1.4900\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 3000 Loss 1.0099\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 3500 Loss 1.7435\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 4000 Loss 1.3663\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 4500 Loss 1.4118\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 5000 Loss 1.7512\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 5500 Loss 1.4753\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 6000 Loss 1.8970\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 6500 Loss 1.7919\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 7000 Loss 1.7885\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 7500 Loss 1.8291\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 16 Batch 8000 Loss 2.0623\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 500 Loss 1.7157\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 1000 Loss 1.2282\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 1500 Loss 1.9662\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 2000 Loss 1.2102\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 2500 Loss 1.3190\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 3000 Loss 1.0750\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 3500 Loss 1.9484\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 4000 Loss 1.1682\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 4500 Loss 1.3932\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 5000 Loss 1.5922\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 5500 Loss 1.2590\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 6000 Loss 1.8247\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 6500 Loss 1.7695\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 7000 Loss 1.5169\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 7500 Loss 1.6748\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 17 Batch 8000 Loss 1.7230\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 500 Loss 1.5400\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 1000 Loss 1.3482\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 1500 Loss 1.9984\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 2000 Loss 1.4036\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 2500 Loss 1.2694\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 3000 Loss 0.8709\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 3500 Loss 2.0164\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 4000 Loss 1.0626\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 4500 Loss 1.5067\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 5000 Loss 1.2103\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 5500 Loss 1.6452\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 6000 Loss 1.7947\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 6500 Loss 1.7642\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 7000 Loss 1.6108\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 7500 Loss 1.7059\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 18 Batch 8000 Loss 1.6170\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 500 Loss 1.7503\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 1000 Loss 1.3273\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 1500 Loss 1.9954\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 2000 Loss 1.2301\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 2500 Loss 1.1561\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 3000 Loss 1.1627\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 3500 Loss 1.8217\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 4000 Loss 0.9770\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 4500 Loss 1.4302\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 5000 Loss 1.4674\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 5500 Loss 1.1998\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 6000 Loss 1.5939\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 6500 Loss 1.5158\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 7000 Loss 1.5588\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 7500 Loss 1.4618\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 19 Batch 8000 Loss 1.7445\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 500 Loss 1.7938\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 1000 Loss 1.0938\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 1500 Loss 1.8695\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 2000 Loss 1.3725\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 2500 Loss 1.3314\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 3000 Loss 1.1921\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 3500 Loss 1.6809\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 4000 Loss 0.9952\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 4500 Loss 1.2521\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 5000 Loss 1.0863\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 5500 Loss 1.4232\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 6000 Loss 1.6082\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 6500 Loss 1.5630\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 7000 Loss 1.5241\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 7500 Loss 1.3576\n',
#  ' ./checkpoints/train/2020-03-03 10:10 Epoch 20 Batch 8000 Loss 1.6487\n']

# %%
loss = [float(x[x.find('Loss') + 5 :].strip()) for x in log]

plt.figure(figsize=(13,13))
plt.plot(loss);
